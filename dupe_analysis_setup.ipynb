# %%
import pandas as pd

# %% [markdown]
# ## File Cleaning

# %% [markdown]
# [Output Data Model](https://dbdiagram.io/d/64594dd7dca9fb07c4b7c4db)

# %% [markdown]
# ### Raw Comments

# %%
SCRAPED_COMMENTS_S3_URL = (
    "https://austin-schaffer.s3.amazonaws.com/virginia-town-hall/scraped-public-comments/"
    "2022+Virginia+Public+Schools+Model+Policy+Public+Comments.csv"
)
comments_raw = pd.read_csv(SCRAPED_COMMENTS_S3_URL, delimiter="|")

print(f"Length: {len(comments_raw.index)}")
comments_raw.head()
# Out:
# Length: 71297
#                                              doc_key       doc_label  \
# 0  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 1  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 2  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 3  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 4  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
#
#                                            doc_title  \
# 0                                        Transgender
# 1  OPPOSE - this will cause actual, real, death o...
# 2  Consequences of Youngkin’s Policy Dire, Immediate
# 3                                    Strongly Oppose
# 4                                            Opposed
#
#                                          doc_content  \
# 0    I am strongly opposed to any law that would ...
# 1    These kids are valid in their identities, ta...
# 2    Gov. Youngkin's model policies regarding tra...
# 3    I strongly oppose the non-evidence based pol...
# 4    "Parents" put a private equity sellout in ch...
#
#                                         doc_original            doc_date  \
# 0   <!DOCTYPE html>  <p>I am strongly opposed to ...   10/27/22  3:07 am
# 1   <!DOCTYPE html>  <p>These kids are valid in t...   10/27/22  1:55 am
# 2   <!DOCTYPE html>  <p>Gov. Youngkin's model pol...  10/27/22  12:06 am
# 3   <!DOCTYPE html>  <p>I <strong>strongly oppose...  10/27/22  12:04 am
# 4   <!DOCTYPE html>  <p>"Parents" put a private e...  10/27/22  12:02 am
#
#                                  doc_author
# 0                          Frank McCullough
# 1                            an APS student
# 2  Martha Molinaro, George Mason University
# 3                        Anonymous (203044)
# 4                        Anonymous (203041)

# %%
name_map = {
    "doc_key": "url",
    "doc_label": "label",
    "doc_title": "title",
    "doc_content": "content",
    "doc_original": "html_raw",
    "doc_date": "created_at",
    "doc_author": "author",
}

comments = comments_raw.rename(columns=name_map)
comments["created_at"] = pd.to_datetime(comments["created_at"])

comments.head()
# Out:
#                                                  url           label  \
# 0  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 1  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 2  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 3  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 4  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
#
#                                                title  \
# 0                                        Transgender
# 1  OPPOSE - this will cause actual, real, death o...
# 2  Consequences of Youngkin’s Policy Dire, Immediate
# 3                                    Strongly Oppose
# 4                                            Opposed
#
#                                              content  \
# 0    I am strongly opposed to any law that would ...
# 1    These kids are valid in their identities, ta...
# 2    Gov. Youngkin's model policies regarding tra...
# 3    I strongly oppose the non-evidence based pol...
# 4    "Parents" put a private equity sellout in ch...
#
#                                             html_raw          created_at  \
# 0   <!DOCTYPE html>  <p>I am strongly opposed to ... 2022-10-27 03:07:00
# 1   <!DOCTYPE html>  <p>These kids are valid in t... 2022-10-27 01:55:00
# 2   <!DOCTYPE html>  <p>Gov. Youngkin's model pol... 2022-10-27 00:06:00
# 3   <!DOCTYPE html>  <p>I <strong>strongly oppose... 2022-10-27 00:04:00
# 4   <!DOCTYPE html>  <p>"Parents" put a private e... 2022-10-27 00:02:00
#
#                                      author
# 0                          Frank McCullough
# 1                            an APS student
# 2  Martha Molinaro, George Mason University
# 3                        Anonymous (203044)
# 4                        Anonymous (203041)

# %% [markdown]
# Extract comment IDs from URLs
#
# - Easier to work with than the URLs
# - Helpful for de-duping the actual comments (the original file has duplicate rows)

# %%
comment_id_regex = (
    r"^https://townhall.virginia.gov/L/viewcomments.cfm\?commentid=(\d+)$"
)
comments["id"] = comments["url"].str.extract(comment_id_regex)

comments.head()
# Out:
#                                                  url           label  \
# 0  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 1  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 2  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 3  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 4  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
#
#                                                title  \
# 0                                        Transgender
# 1  OPPOSE - this will cause actual, real, death o...
# 2  Consequences of Youngkin’s Policy Dire, Immediate
# 3                                    Strongly Oppose
# 4                                            Opposed
#
#                                              content  \
# 0    I am strongly opposed to any law that would ...
# 1    These kids are valid in their identities, ta...
# 2    Gov. Youngkin's model policies regarding tra...
# 3    I strongly oppose the non-evidence based pol...
# 4    "Parents" put a private equity sellout in ch...
#
#                                             html_raw          created_at  \
# 0   <!DOCTYPE html>  <p>I am strongly opposed to ... 2022-10-27 03:07:00
# 1   <!DOCTYPE html>  <p>These kids are valid in t... 2022-10-27 01:55:00
# 2   <!DOCTYPE html>  <p>Gov. Youngkin's model pol... 2022-10-27 00:06:00
# 3   <!DOCTYPE html>  <p>I <strong>strongly oppose... 2022-10-27 00:04:00
# 4   <!DOCTYPE html>  <p>"Parents" put a private e... 2022-10-27 00:02:00
#
#                                      author      id
# 0                          Frank McCullough  203047
# 1                            an APS student  203046
# 2  Martha Molinaro, George Mason University  203045
# 3                        Anonymous (203044)  203044
# 4                        Anonymous (203041)  203041

# %%
comments["full_text"] = comments["title"] + " " + comments["content"]
comments["full_text"] = comments["full_text"].replace("\xa0", "", regex=True).fillna("")

comments.head()
# Out:
#                                                  url           label  \
# 0  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 1  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 2  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 3  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 4  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
#
#                                                title  \
# 0                                        Transgender
# 1  OPPOSE - this will cause actual, real, death o...
# 2  Consequences of Youngkin’s Policy Dire, Immediate
# 3                                    Strongly Oppose
# 4                                            Opposed
#
#                                              content  \
# 0    I am strongly opposed to any law that would ...
# 1    These kids are valid in their identities, ta...
# 2    Gov. Youngkin's model policies regarding tra...
# 3    I strongly oppose the non-evidence based pol...
# 4    "Parents" put a private equity sellout in ch...
#
#                                             html_raw          created_at  \
# 0   <!DOCTYPE html>  <p>I am strongly opposed to ... 2022-10-27 03:07:00
# 1   <!DOCTYPE html>  <p>These kids are valid in t... 2022-10-27 01:55:00
# 2   <!DOCTYPE html>  <p>Gov. Youngkin's model pol... 2022-10-27 00:06:00
# 3   <!DOCTYPE html>  <p>I <strong>strongly oppose... 2022-10-27 00:04:00
# 4   <!DOCTYPE html>  <p>"Parents" put a private e... 2022-10-27 00:02:00
#
#                                      author      id  \
# 0                          Frank McCullough  203047
# 1                            an APS student  203046
# 2  Martha Molinaro, George Mason University  203045
# 3                        Anonymous (203044)  203044
# 4                        Anonymous (203041)  203041
#
#                                            full_text
# 0  Transgender   I am strongly opposed to any law...
# 1  OPPOSE - this will cause actual, real, death o...
# 2  Consequences of Youngkin’s Policy Dire, Immedi...
# 3  Strongly Oppose   I strongly oppose the non-ev...
# 4  Opposed   "Parents" put a private equity sello...

# %% [markdown]
# ### Duplicate Groups

# %% [markdown]
# Load group<->comment map

# %%
dupe_group_comments = pd.read_csv("data/group_df.csv", index_col=0)

dupe_group_comments.head()
# Out:
#    group_number  index
# 0             0  34684
# 1             0  36840
# 2             0  36832
# 3             0  36831
# 4             0  36827

# %% [markdown]
# Map the actual comment IDs instead of the random index

# %%
dupe_group_comments = pd.merge(
    dupe_group_comments,
    comments,
    left_on="index",
    right_index=True,
)[["group_number", "comment_id"]]

# %%
dupe_group_comments = dupe_group_comments.rename(columns={"group_number": "group_id"})

dupe_group_comments.head()
# Out:
#    group_id comment_id
# 0         0     165765
# 1         0     163606
# 2         0     163609
# 3         0     163613
# 4         0     163616

# %% [markdown]
# Double check the lookups work

# %%
comments.set_index("comment_id").loc[
    dupe_group_comments.loc[dupe_group_comments["group_id"] == 3, "comment_id"]
].head(3)
# Out:
#                                                           url           label  \
# comment_id
# 136829      https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 130262      https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 130264      https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
#
#                            title                  content  \
# comment_id
# 136829      I fully oppose this.    I fully oppose this.
# 130262      I fully oppose this.    I fully oppose this.
# 130264      I oppose this fully.    I oppose this fully.
#
#                                                   html_raw  \
# comment_id
# 136829       <!DOCTYPE html>  <p>I fully oppose this.</p>
# 130262       <!DOCTYPE html>  <p>I fully oppose this.</p>
# 130264       <!DOCTYPE html>  <p>I oppose this fully.</p>
#
#                     created_at          author  \
# comment_id
# 136829     2022-09-26 16:55:00  Sidney Liesman
# 130262     2022-09-26 12:41:00      Miah Leden
# 130264     2022-09-26 12:42:00   Dayton Korach
#
#                                                full_text
# comment_id
# 136829      I fully oppose this.   I fully oppose this.
# 130262      I fully oppose this.   I fully oppose this.
# 130264      I oppose this fully.   I oppose this fully.

# %% [markdown]
# Attach a sample comment per group

# %%
dupe_groups = dupe_group_comments.groupby("group_id", as_index=False).first()

dupe_groups = pd.merge(
    dupe_groups, comments, left_on="comment_id", right_on="comment_id", how="left"
)

dupe_groups = dupe_groups[["group_id", "full_text"]].rename(
    columns={
        "group_id": "id",
        "full_text": "sample_comment_text",
    }
)

dupe_groups.head()
# Out:
#    id                                sample_comment_text
# 0   0  Leave Trans Kids Alone   This will hurt kids. ...
# 1   1  Strongly Oppose   This will hurt kids. Don't b...
# 2   2  Youngkin Hates   This will hurt kids. Don't be...
# 3   3       I fully oppose this.   I fully oppose this.
# 4   4  Glenn Youngkin Is A Bot   This will hurt kids....

# %% [markdown]
# ## Deduplicate the Comments
#
# Didn't do this above because some of the groups might map to the duplicates

# %%
comments = comments[~comments["id"].duplicated()]

# %%
len(comments.index)
# Out:
# 71277

# %% [markdown]
# ### Sentiment Labels

# %% [markdown]
# Updated classifications

# %%
columns = [
    "doc_key",
    "doc_title",
    "doc_date",
    "doc_author",
    "doc_total",
    "oppose_mean_similarity",
    "support_mean_similarity",
    "ambig_mean_similarity",
    "sentiment_mean_predict",
    "match_title",
    "match_key",
    "match_mean_sentiment",
]

labeled = pd.read_excel(
    "data/labeledcomments_20230508.xlsx",
    usecols=columns,
)

print(f"Length: {len(labeled.index)}")
labeled.head()
# Out:
# Length: 71768
#                                              doc_key  \
# 0  https://townhall.virginia.gov/L/viewcomments.c...
# 1  https://townhall.virginia.gov/L/viewcomments.c...
# 2  https://townhall.virginia.gov/L/viewcomments.c...
# 3  https://townhall.virginia.gov/L/viewcomments.c...
# 4  https://townhall.virginia.gov/L/viewcomments.c...
#
#                                            doc_title              doc_date  \
# 0                                        Transgender   10/27/22Â Â 3:07 am
# 1                      I strongly oppose this policy  10/26/22Â Â 10:35 pm
# 2                                    Strongly Oppose   10/26/22Â Â 9:43 pm
# 3                                    Strongly oppose   10/26/22Â Â 6:18 pm
# 4  SUPPORT 1000% It is NOT kind or LOVING to lie ...   10/26/22Â Â 4:53 pm
#
#                             doc_author  \
# 0                     Frank McCullough
# 1                   Anonymous (202557)
# 2                 Father of trans girl
# 3                   Anonymous (201186)
# 4  Honest parent for truth and biology
#
#                                            doc_total oppose_mean_similarity  \
# 0  Transgender  I am strongly opposed to any law ...               0.433871
# 1  I strongly oppose this policy  This policy whi...               0.437536
# 2             Strongly Oppose  Father of trans girl                0.761039
# 3  Strongly oppose  Children should not be able t...               0.468895
# 4  SUPPORT 1000% It is NOT kind or LOVING to lie ...               0.296143
#
#   support_mean_similarity ambig_mean_similarity sentiment_mean_predict  \
# 0                0.340971              0.225158                Opposed
# 1                0.307242              0.255222                Opposed
# 2                0.086021               0.15294                Opposed
# 3                0.338169              0.192935                Opposed
# 4                0.354949              0.348908                Support
#
#        match_title                                          match_key  \
# 0  Strongly Oppose  https://townhall.virginia.gov/L/viewcomments.c...
# 1  Strongly Oppose  https://townhall.virginia.gov/L/viewcomments.c...
# 2  Strongly Oppose  https://townhall.virginia.gov/L/viewcomments.c...
# 3  Strongly Oppose  https://townhall.virginia.gov/L/viewcomments.c...
# 4  Strongly Oppose  https://townhall.virginia.gov/L/viewcomments.c...
#
#   match_mean_sentiment
# 0              Opposed
# 1              Opposed
# 2              Opposed
# 3              Opposed
# 4              Opposed

# %%
labeled["comment_id"] = labeled["doc_key"].str.extract(comment_id_regex)

labeled.head()
# Out:
#                                              doc_key  \
# 0  https://townhall.virginia.gov/L/viewcomments.c...
# 1  https://townhall.virginia.gov/L/viewcomments.c...
# 2  https://townhall.virginia.gov/L/viewcomments.c...
# 3  https://townhall.virginia.gov/L/viewcomments.c...
# 4  https://townhall.virginia.gov/L/viewcomments.c...
#
#                                            doc_title              doc_date  \
# 0                                        Transgender   10/27/22Â Â 3:07 am
# 1                      I strongly oppose this policy  10/26/22Â Â 10:35 pm
# 2                                    Strongly Oppose   10/26/22Â Â 9:43 pm
# 3                                    Strongly oppose   10/26/22Â Â 6:18 pm
# 4  SUPPORT 1000% It is NOT kind or LOVING to lie ...   10/26/22Â Â 4:53 pm
#
#                             doc_author  \
# 0                     Frank McCullough
# 1                   Anonymous (202557)
# 2                 Father of trans girl
# 3                   Anonymous (201186)
# 4  Honest parent for truth and biology
#
#                                            doc_total oppose_mean_similarity  \
# 0  Transgender  I am strongly opposed to any law ...               0.433871
# 1  I strongly oppose this policy  This policy whi...               0.437536
# 2             Strongly Oppose  Father of trans girl                0.761039
# 3  Strongly oppose  Children should not be able t...               0.468895
# 4  SUPPORT 1000% It is NOT kind or LOVING to lie ...               0.296143
#
#   support_mean_similarity ambig_mean_similarity sentiment_mean_predict  \
# 0                0.340971              0.225158                Opposed
# 1                0.307242              0.255222                Opposed
# 2                0.086021               0.15294                Opposed
# 3                0.338169              0.192935                Opposed
# 4                0.354949              0.348908                Support
#
#        match_title                                          match_key  \
# 0  Strongly Oppose  https://townhall.virginia.gov/L/viewcomments.c...
# 1  Strongly Oppose  https://townhall.virginia.gov/L/viewcomments.c...
# 2  Strongly Oppose  https://townhall.virginia.gov/L/viewcomments.c...
# 3  Strongly Oppose  https://townhall.virginia.gov/L/viewcomments.c...
# 4  Strongly Oppose  https://townhall.virginia.gov/L/viewcomments.c...
#
#   match_mean_sentiment comment_id
# 0              Opposed     203047
# 1              Opposed     202557
# 2              Opposed     202191
# 3              Opposed     201186
# 4              Opposed     200115

# %% [markdown]
# Will need to fix!

# %%
labeled = labeled[~labeled["comment_id"].isna()]

# %%
labeled["comment_id"] = labeled["comment_id"].astype(int)

# %%
len(labeled.index)
# Out:
# 71297

# %%
labeled = labeled[~labeled["comment_id"].duplicated()]

# %%
len(labeled.index)
# Out:
# 71277

# %%
needed_cols = [
    "comment_id",
    "oppose_mean_similarity",
    "support_mean_similarity",
    "ambig_mean_similarity",
    "sentiment_mean_predict",
    "match_title",
    "match_key",
    "match_mean_sentiment",
]

labeled = labeled.loc[:, needed_cols]

labeled.head()
# Out:
#    comment_id oppose_mean_similarity support_mean_similarity  \
# 0      203047               0.433871                0.340971
# 1      202557               0.437536                0.307242
# 2      202191               0.761039                0.086021
# 3      201186               0.468895                0.338169
# 4      200115               0.296143                0.354949
#
#   ambig_mean_similarity sentiment_mean_predict      match_title  \
# 0              0.225158                Opposed  Strongly Oppose
# 1              0.255222                Opposed  Strongly Oppose
# 2               0.15294                Opposed  Strongly Oppose
# 3              0.192935                Opposed  Strongly Oppose
# 4              0.348908                Support  Strongly Oppose
#
#                                            match_key match_mean_sentiment
# 0  https://townhall.virginia.gov/L/viewcomments.c...              Opposed
# 1  https://townhall.virginia.gov/L/viewcomments.c...              Opposed
# 2  https://townhall.virginia.gov/L/viewcomments.c...              Opposed
# 3  https://townhall.virginia.gov/L/viewcomments.c...              Opposed
# 4  https://townhall.virginia.gov/L/viewcomments.c...              Opposed

# %% [markdown]
# ## Write Files

# %%
path_prefix = "data/model"

# %%
comments = comments[["id", *name_map.values(), "full_text"]]

# %%
comments.head(2)
# Out:
#        id                                                url           label  \
# 0  203047  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
# 1  203046  https://townhall.virginia.gov/L/viewcomments.c...  not_applicable
#
#                                                title  \
# 0                                        Transgender
# 1  OPPOSE - this will cause actual, real, death o...
#
#                                              content  \
# 0    I am strongly opposed to any law that would ...
# 1    These kids are valid in their identities, ta...
#
#                                             html_raw          created_at  \
# 0   <!DOCTYPE html>  <p>I am strongly opposed to ... 2022-10-27 03:07:00
# 1   <!DOCTYPE html>  <p>These kids are valid in t... 2022-10-27 01:55:00
#
#              author                                          full_text
# 0  Frank McCullough  Transgender   I am strongly opposed to any law...
# 1    an APS student  OPPOSE - this will cause actual, real, death o...

# %%
comments.to_csv(
    f"{path_prefix}/comments.csv",
    index=False,
)

# %%
dupe_group_comments.head(2)
# Out:
#    group_id comment_id
# 0         0     165765
# 1         0     163606

# %%
dupe_group_comments.to_csv(
    f"{path_prefix}/dupe_group_comments.csv",
    index=False,
)

# %%
dupe_groups.head(2)
# Out:
#    id                                sample_comment_text
# 0   0  Leave Trans Kids Alone   This will hurt kids. ...
# 1   1  Strongly Oppose   This will hurt kids. Don't b...

# %%
dupe_groups.to_csv(
    f"{path_prefix}/dupe_groups.csv",
    index=False,
)

# %%
labeled.head(2)
# Out:
#    comment_id oppose_mean_similarity support_mean_similarity  \
# 0      203047               0.433871                0.340971
# 1      202557               0.437536                0.307242
#
#   ambig_mean_similarity sentiment_mean_predict      match_title  \
# 0              0.225158                Opposed  Strongly Oppose
# 1              0.255222                Opposed  Strongly Oppose
#
#                                            match_key match_mean_sentiment
# 0  https://townhall.virginia.gov/L/viewcomments.c...              Opposed
# 1  https://townhall.virginia.gov/L/viewcomments.c...              Opposed

# %%
labeled.to_csv(
    f"{path_prefix}/classifications.csv",
    index=False,
)
